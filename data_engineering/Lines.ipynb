# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
data = pd.read_excel('data_engineering/Line_info_cheikh.xlsx', sheet_name=0, engine='openpyxl')

# %%
data.head()
# Out:
#    Unnamed: 0              Unnamed: 1 Unnamed: 2                Unnamed: 3  \
# 0         NaN  CARACTERISTIQUES LIGNE        NaN                       NaN
# 1         1.0                    SITE      LIGNE  CADENCE NOMINALE (uvp/h)
# 2         2.0                     RSN        DE1                      5400
# 3         3.0                     RSN        DE2                      5280
# 4         4.0                     RSN        DE3                      5280
#
#                         Unnamed: 4                Unnamed: 5  \
# 0                              NaN  CARACTERISTIQUES PRODUIT
# 1                           Goulot            Format découpe
# 2                      Encaisseuse                       D32
# 3  Encaisseuse + Ilapak Delta 3000           REC 26x32 / D32
# 4           Encaisseuse + Flowpack           REC 26x32 / D32
#
#          Unnamed: 6        Unnamed: 7 Unnamed: 8      Unnamed: 9  ...  \
# 0               NaN               NaN        NaN             NaN  ...
# ...

# %%
df_lines = data.copy()
df_lines.columns
# Out:
# Index([  'Unnamed: 0',   'Unnamed: 1',   'Unnamed: 2',   'Unnamed: 3',
#          'Unnamed: 4',   'Unnamed: 5',   'Unnamed: 6',   'Unnamed: 7',
#          'Unnamed: 8',   'Unnamed: 9',
#        ...
#         'Unnamed: 91',  'Unnamed: 92',  'Unnamed: 93',  'Unnamed: 94',
#         'Unnamed: 95',  'Unnamed: 96',  'Unnamed: 97',  'Unnamed: 98',
#         'Unnamed: 99', 'Unnamed: 100'],
#       dtype='object', length=101)

# %%
df_lines = df_lines.iloc[:, [1, 2,3,8,9,22]]

# %%
df_lines
# Out:
#                  Unnamed: 1 Unnamed: 2                Unnamed: 3 Unnamed: 8  \
# 0    CARACTERISTIQUES LIGNE        NaN                       NaN        NaN
# 1                      SITE      LIGNE  CADENCE NOMINALE (uvp/h)  Catégorie
# 2                       RSN        DE1                      5400        PAT
# 3                       RSN        DE2                      5280        PAT
# 4                       RSN        DE3                      5280        PAT
# ..                      ...        ...                       ...        ...
# 110                 Kit PZR         FP                       NaN        NaN
# 111             Gluten Free         FP                       NaN        NaN
# 112                Brötchen        CAN                       NaN        NaN
# 113               Breakfast        CAN                       NaN        NaN
# 114              Tartelette  FP + étui                       NaN        NaN
#
#          Unnamed: 9 Unnamed: 22
# ...

# %%
df_lines = df_lines[df_lines[df_lines.columns[-1]].notna()]

# %%
df_lines.tail(15)
# Out:
#    Unnamed: 1 Unnamed: 2 Unnamed: 3                   Unnamed: 8  \
# 77        SLB       SL12       6240              Breakfast dough
# 78        SLB       SL12       6480              Breakfast dough
# 79        SLB       SL13      10380  Breakfast dough - Kit Pizza
# 80        SLB       SL13       8460                    Kit Pizza
# 81        SLB       SL13      12600              Breakfast dough
# 82        SLB       SL13      10080              Breakfast dough
# 83        HUM         K1       3300                          PAT
# 84        HUM         K1       3400                          PAT
# 85        HUM         K1       3300                          PZR
# 86        HUM         K1       3000                          PZR
# 87        HUM         K2       4000                          PZR
# 88        HUM         K2       4300                          PZR
# 89        HUM         K2       3800                          PZR
# ...

# %%
df_lines.rename(columns={'Unnamed: 1': 'Site',
                         'Unnamed: 2': 'Name',
                         'Unnamed: 3': 'Uvc/h',
                         'Unnamed: 8': 'Category',
                         'Unnamed: 9': 'Subcategory',
                         'Unnamed: 22': 'Efficiency'}, inplace=True)
# Out:
# C:\Users\cdeme\AppData\Local\Temp\4\ipykernel_14384\1725963365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lines.rename(columns={'Unnamed: 1': 'Site',

# %%
df_lines
# Out:
#                       Site   Name                     Uvc/h   Category  \
# 0   CARACTERISTIQUES LIGNE    NaN                       NaN        NaN
# 1                     SITE  LIGNE  CADENCE NOMINALE (uvp/h)  Catégorie
# 2                      RSN    DE1                      5400        PAT
# 3                      RSN    DE2                      5280        PAT
# 4                      RSN    DE3                      5280        PAT
# ..                     ...    ...                       ...        ...
# 87                     HUM     K2                      4000        PZR
# 88                     HUM     K2                      4300        PZR
# 89                     HUM     K2                      3800        PZR
# 90                     HUM     K2                      3000  Kit Pizza
# 92                     HUM     K4                       NaN        NaN
#
#        Subcategory  Efficiency
# 0              NaN         OEE
# 1   Sous-Catégorie  OEE BUFY25
# ...

# %%
df_lines = df_lines.iloc[2:].reset_index(drop=True)
df_lines
# Out:
#    Site Name Uvc/h   Category Subcategory Efficiency
# 0   RSN  DE1  5400        PAT         PBR      0.835
# 1   RSN  DE2  5280        PAT         PBR       0.78
# 2   RSN  DE3  5280        PAT         PAT      0.845
# 3   RSN  DE4  5400        PAT         PAT       0.82
# 4   RSN  DE5  5400        PAT    PAT étui       0.82
# ..  ...  ...   ...        ...         ...        ...
# 81  HUM   K2  4000        PZR         PZR        0.8
# 82  HUM   K2  4300        PZR         PZR        0.8
# 83  HUM   K2  3800        PZR         PZR        0.8
# 84  HUM   K2  3000  Kit Pizza  Kit PZR FP        0.8
# 85  HUM   K4   NaN        NaN         NaN        0.8
#
# [86 rows x 6 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df_lines
# Out:
#    Site             Name  Uvc/h                     Category  \
# 0   RSN              DE1   5400                          PAT
# 1   RSN              DE2   5280                          PAT
# 2   RSN              DE3   5280                          PAT
# 3   RSN              DE4   5400                          PAT
# 4   RSN              DE5   5400                          PAT
# 5   RSN              DE6   5160                          PAT
# 6   RSN              DE7   5280                          PAT
# 7   RSN  DE7 kit galette   5280                          PAT
# 8   RSN              DE8   5100                          PAT
# 9   VIT               L1   5055                          PAT
# 10  VIT               L1   5160                          PAT
# 11  VIT               L1   4500                          PAT
# 12  VIT               L3   4650                          PZR
# 13  VIT               L3   4800                          PZR
# ...
